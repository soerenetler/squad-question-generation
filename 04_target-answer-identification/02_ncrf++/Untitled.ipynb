# %%
# !python NCRFpp/main.py --config squad.train.config
# Out:
# Seed num: 42
# MODEL: train
# Load pretrained word embedding, norm: False, dir: NCRFpp/sample_data/sample.word.emb
# Embedding:
#      pretrain word:15093, prefect match:4439, case_match:1710, oov:11828, oov%:0.6579152297252198
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 250
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 17978
#      Char  alphabet size: 267
#      Label alphabet size: 4
#      Word embedding  dir: NCRFpp/sample_data/sample.word.emb
#      Char embedding  dir: None
#      Word embedding size: 50
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: squad.train.bio
# ...
